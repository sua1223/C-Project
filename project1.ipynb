# %% [markdown]
# # Project 1. 전화번호 구현하기

# %% [markdown]
# ## 프 로 젝 트 목 차
# <pre>
# Project 1. 전화번호부 구현하기
# 	1.1. 선택창 만들기
# 		1.1.1) 선택창 출력하기
# 		1.1.2) 메뉴 입력받기
# 	1.2. 입력 함수 작성하기
# 		1.2.1) 입력받아 저장하기
# 		1.2.2) 함수 선언하기
# 	1.3. 수정 함수 작성하기
# 		1.3.1) 수정할 값 검색하기
# 		1.3.2) 전화번호 수정하기
# 	1.4. 삭제 함수 작성하기
# 		1.4.1) 삭제할 값 검색하기
# 		1.4.2) 전화번호 삭제하기
# 	1.5. 검색 함수 작성하기
# 		1.5.1) 검색하기
# 		1.5.2) 전화번호 출력하기
# 	1.6. 저장 함수 작성하기
# 		1.6.1) 파일 입출력

# %% [markdown]
# ### Project 1. 소개
# 주제: 전화번호부 구현하기<br>
# 내용: 콘솔창에서 전화번호를 입력, 수정, 삭제, 검색할 수 있으며 저장 버튼을 누르면 전화번호가 파일로 저장되는 프로그램을 만들 것이다.<br>
#
# 프로그램 기능<br>
# 1. 입력: 이름과 전화번호를 입력한다. 최대 저장 가능 공간은 100으로 한다.
# 2. 수정: 입력된 전화번호를 수정한다. 이름으로 검색하여 해당하는 사람의 전화번호를 수정한다.
# 3. 삭제: 입력된 전화번호를 삭제한다. 이름으로 검색하여 해당하는 사람의 전화번호를 삭제한다.
# 4. 검색: 이름을 검새하면 해당하는 사람의 전화번호를 출력한다.
# 5. 저장: 입력된 이름과 전화번호들을 파일로 저장한다.
# 사용자가 종료를 입력하기 전까지 프로그램이 반복된다.

# %% [markdown]
# ### 1.1) 선택창 만들기

# %% [markdown]
# #### 1.1 - 예제문제1)
# scanf를 이용하여 숫자를 입력받고 출력하시오.

# %% [markdown]
# <결과화면>
# ![image.png](attachment:image.png)

# %% [markdown]
# <해답>

# %%
#include <stdio.h>

int main() {
	int n;
	printf("숫자를 입력하세요: ");
	scanf("%d", &n);

	printf("%d\n", n);
}
# Out:
#   File "<ipython-input-1-85e0c15ed02e>", line 3
#     int main() {
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### 1.1 - 예제 문제2)
# 숫자를 입력받고 입력받은 숫자를 if문으로 판별하시오

# %% [markdown]
# <결과 화면>
# ![image.png](attachment:image.png)

# %% [markdown]
# <해답>

# %%
#include <stdio.h>

int main() {
	int n;
	printf("숫자를 입력하세요: ");
	scanf("%d", &n);

	if (n == 1)
		printf("입력받은 숫자는 1입니다.\n");
	else
		printf("입력받은 숫자는 1이 아닙니다.\n");
}
# Out:
#   File "<ipython-input-2-eab7bc76499c>", line 3
#     int main() {
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### 1.1 – 예제문제 3)
# 1이 나올 때까지 숫자를 계속 입력 받는 무한루프를 while문을 이용하여 만드시오.

# %% [markdown]
# <결과 화면>
# ![image.png](attachment:image.png)

# %% [markdown]
# <해답>

# %%
#include <stdio.h>

int main() {
	int n;

	while (1) {
		printf("숫자를 입력하세요: ");
		scanf("%d", &n);

		if (n == 1) {
			printf("1을 눌러 프로그램을 종료합니다.\n");
			break;
		}
	}
}
# Out:
#   File "<ipython-input-3-ee181ed3caf2>", line 3
#     int main() {
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### 1.1.1) 선택창 출력하기

# %% [markdown]
# #### 1.1.1 – 실습문제 1)
# 결과화면과 같게 printf를 이용해 선택창을 출력하시오.

# %% [markdown]
# <결과 화면>
# ![image.png](attachment:image.png)

# %% [markdown]
# <해답>

# %%
#include <stdio.h>

int main() {
	printf("*************전화번호부*************\n\n");
	printf("    1.입력    2.수정    3.삭제\n");
	printf("    4.검색    5.저장    6.종료\n");
	printf("************************************\n");
}
# Out:
#   File "<ipython-input-4-c04d000273ae>", line 3
#     int main() {
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### 1.1.1 – 실습문제 2)
# 실습문제 1과 같은 선택창을 출력한 후, 무한루프를 이용해 6.종료를 입력 받을 때까지 계속해서 번호를 입력받아라. 각 번호에 따라 호출되는 함수들은 다음과 같으며 main함수 위에 선언해둔다.<br>
# 1.입력: void input()   2.수정: void edit()   3.삭제: void erase() 4.검색: void search()  5.저장: void save()

# %% [markdown]
# <해답>

# %%
#include <stdio.h>

void input();
void edit();
void erase();
void search();
void save();

int main() {
	
	int menu = 0;

	while (1) {
		printf("\n사용자 입력>> ");
		scanf("%d", &menu);

		if (menu == 6)
			break;
		else if (menu == 1)
			input();
		else if (menu == 2)
			edit();
		else if (menu == 3)
			erase();
		else if (menu == 4)
			search();
		else if (menu == 5)
			save();
		else
			printf("잘못된 입력입니다. 다시 입력하세요,\n");
	}
 }
# Out:
#   File "<ipython-input-5-a3f64b3bc10f>", line 3
#     void input();
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Sub-Project 1. 선택창 만들기

# %% [markdown]
# 주제: 기능들이 담긴 선택창을 출력하고, 특정 번호를 입력하면 특정 기능을 실행하는 함수를 호출하도록 한다. 종료 버튼을 입력할 때까지 프로그램이 무한으로 반복되며 기능들은 다음과 같다. 잘못된 입력일 경우 예외처리 해준다.<br>
# 1.입력: input() 2.수정: edit() 3.삭제: erase() 4.검색: search() 5.저장: save() 6. 종료

# %% [markdown]
# <결과 화면>
# ![image.png](attachment:image.png)

# %% [markdown]
# <해답>

# %%
#include <stdio.h>
#include <string.h>
#define SIZE 30
#define MAX_SIZE 100

char name[MAX_SIZE][SIZE]; // 이름을 저장하는 배열
char phone[MAX_SIZE][SIZE]; // 전화번호를 저장하는 배열
int num = 0; // 사람과 전화번호를 num 변수로 연결

void input();
void edit();
void erase();
void search();
void save();

int main() {

	printf("*************전화번호부*************\n\n");
	printf("    1.입력    2.수정    3.삭제\n");
	printf("    4.검색    5.저장    6.종료\n");
	printf("************************************\n");

	int menu = 0;

	while (1) {
		printf("\n사용자 입력>> ");
		scanf("%d", &menu);

		if (menu == 6)
			break;
		else if (menu == 1)
			input();
		else if (menu == 2)
			edit();
		else if (menu == 3)
			erase();
		else if (menu == 4)
			search();
		else if (menu == 5)
			save();
		else
			printf("잘못된 입력입니다. 다시 입력하세요,\n");
	}
}
# Out:
#   File "<ipython-input-6-3ba0cb4172aa>", line 6
#     char name[MAX_SIZE][SIZE]; // 이름을 저장하는 배열
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 1.2) 전화번호 입력받기

# %% [markdown]
# #### 1.2 - 예제문제 1)
# #define을 이용하여 MAX 값을 10으로 매크로 지정해주어 “Hellow World”를 MAX 만큼 출력하시오.

# %% [markdown]
# <결과 화면>
# ![image.png](attachment:image.png)

# %% [markdown]
# <해답>

# %%
#include <stdio.h>

#define MAX 10
int main() {
	for (int i = 0; i < MAX; i++) {
		printf("Hello World\n");
	}
}
# Out:
#   File "<ipython-input-7-a26b72e210cc>", line 4
#     int main() {
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### 1.2 – 예제문제 2)
# char형 배열을 이용하여 문자열을 입력받아 출력하시오.

# %% [markdown]
# <결과 화면>
# ![image.png](attachment:image.png)

# %% [markdown]
# <해답>

# %%
#include <stdio.h>

int main() {
	char c[30];
	printf("문자열을 입력하세요: ");
	scanf("%s", c);
	printf("%s\n", c);
}
# Out:
#   File "<ipython-input-8-c1867cb3f165>", line 3
#     int main() {
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### 1.2 – 예제문제 3)
# 0부터 9까지 출력하는 사용자 함수를 정의하여 작성하시오. 함수명은 print_num() 이며, main 함수 밖에서 정의하고 main 함수에서 해당 함수를 호출하시오.

# %% [markdown]
# <결과 화면>
# ![image.png](attachment:image.png)

# %% [markdown]
# <해답>

# %%
#include <stdio.h>

int num[10];
void print_num() {
	for (int i = 0; i < 10; i++) {
		printf("%d ", num[i]);
	}
	printf("\n");
}

int main() {
	for (int i = 0; i < 10; i++) {
		num[i] = i;
	}
	print_num();
}
# Out:
#   File "<ipython-input-9-101c93e8d546>", line 3
#     int num[10];
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 1.2.1) 입력받아 저장하기

# %% [markdown]
# #### 1.2.1 - 실습문제 1)
# 이름과 전화번호를 저장할 2차원 배열을 전역으로 선언하고, 입력 받아 저장한다.

# %% [markdown]
# <해답>

# %%
#include <stdio.h>
#define SIZE 30
#define MAX_SIZE 100

char name[MAX_SIZE][SIZE]; // 이름을 저장하는 배열
char phone[MAX_SIZE][SIZE]; // 전화번호를 저장하는 배열
int num = 0; // 사람과 전화번호를 num 변수로 연결

int main() {
	printf("이름: ");
	scanf("%s", name[num]);

	printf("전화번호: ");
	scanf("%s", phone[num]);
 }
# Out:
#   File "<ipython-input-10-410dca3ee184>", line 5
#     char name[MAX_SIZE][SIZE]; // 이름을 저장하는 배열
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Sub-Project 2. 입력 함수 구현하기
# 주제: 사용자로부터 이름과 전화번호를 문자열로 입력받아 저장하는 함수를 구현한다. 이름을 저장하는 배열과 전화번호를 저장하는 배열을 전역변수로 선언하고, 최대 입력 받을 수 있는 개수는 100개로 제한한다. 입력받은 이름과 전화번호의 인덱스는 하나의 변수로 연결시킨다.  함수명은 input() 이다.

# %% [markdown]
# <결과 화면>
# ![image.png](attachment:image.png)

# %% [markdown]
# <해답>

# %%
#include <string.h>
#define SIZE 30
#define MAX_SIZE 100

char name[MAX_SIZE][SIZE]; // 이름을 저장하는 배열
char phone[MAX_SIZE][SIZE]; // 전화번호를 저장하는 배열
int num = 0; // 사람과 전화번호를 num 변수로 연결

// 전화번호를 새로 입력하는 함수
void input() {

	if (num >= MAX_SIZE) {
	printf("저장공간이 부족합니다.\n");
	return;
	}

	printf("이름: ");
	scanf("%s", name[num]);

	printf("전화번호: ");
	scanf("%s", phone[num]);

	num++;
}
# Out:
#   File "<ipython-input-11-a37f1235bf5c>", line 5
#     char name[MAX_SIZE][SIZE]; // 이름을 저장하는 배열
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 1.3) 수정 함수 작성하기

# %% [markdown]
# #### 1.3 – 예제문제 1)
# 문자열 두 개를 strcmp로 비교하여 같을 경우 같다고, 다를 경우 다르다고 출력하시오.

# %% [markdown]
# <결과 화면>
# ![image.png](attachment:image.png)

# %% [markdown]
# <해답>

# %%
#include <stdio.h>
#include <string.h>

int main() {
	char s1[10] = "Hello";
	char s2[10] = "hi";

	if (strcmp(s1, s2)==0)
		printf("두 문자열이 같습니다.\n");
	else
		printf("두 문자열이 다릅니다.\n");
}
# Out:
#   File "<ipython-input-12-1974b558eeff>", line 4
#     int main() {
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### 1.3 – 예제문제 2)
# strcpy를 사용하여 1번 문자열을 2번 문자열로 복사한 후, 2번 문자열을 출력하시오.

# %% [markdown]
# <결과 화면>
# ![image.png](attachment:image.png)

# %% [markdown]
# <해답>

# %%
#include <stdio.h>
#include <string.h>

int main() {
	char s1[10] = "Hello";
	char s2[10];

	strcpy(s2, s1);
	printf("%s\n", s2);
}

# %% [markdown]
# ### 1.3.1) 수정할 값 검색하기

# %% [markdown]
# #### 1.3.1 - 실습문제 1)
# 수정할 사람의 이름을 입력받으시오.

# %% [markdown]
# <해답>

# %%
#include <stdio.h>
#include <string.h>
#define SIZE 30
#define MAX_SIZE 100
char name[MAX_SIZE][SIZE]; 
char phone[MAX_SIZE][SIZE]; 
int num = 0;

int main() {
	char edit_name[SIZE]; // 수정할 사람의 이름

	printf("전화번호를 수정할 사람의 이름을 입력하세요: ");
	scanf("%s", edit_name);
}
# Out:
#   File "<ipython-input-13-8ec69bb09ce5>", line 5
#     char name[MAX_SIZE][SIZE];
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### 1.3.1 – 실습문제 2)
# name 배열에서 수정할 사람을 검색하고, 찾은 사람의 인덱스를 다른 변수에 저장하시오.

# %% [markdown]
# <해답>

# %%
#include <stdio.h>
#include <string.h>
#define SIZE 30
#define MAX_SIZE 100
char name[MAX_SIZE][SIZE];
char phone[MAX_SIZE][SIZE];
int num = 0;

int main() {
	char edit_name[SIZE]; // 수정할 사람의 이름
	int edit_index; // 수정할 사람이 저장된 인덱스

	printf("전화번호를 수정할 사람의 이름을 입력하세요: ");
	scanf("%s", edit_name);
	
	// 수정할 사람 검색
	for (int i = 0; i < num; i++) {
		if (strcmp(edit_name, name[i]) == 0) 
			edit_index = i; 
	}
}
# Out:
#   File "<ipython-input-14-449384c9ce91>", line 5
#     char name[MAX_SIZE][SIZE];
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### 1.3.1 – 실습문제 3)
# 검색한 값이 없을 경우 존재하지 않는 이름이라는 문구를 출력하시오. 이때 검색에 성공했을 경우 인덱스를 저장할 초기값을 설정하여 구분하면 쉽다.

# %% [markdown]
# <해답>

# %%
#include <stdio.h>
#include <string.h>
#define SIZE 30
#define MAX_SIZE 100
char name[MAX_SIZE][SIZE];
char phone[MAX_SIZE][SIZE];
int num = 0;

int main() {
	char edit_name[SIZE]; // 수정할 사람의 이름
	int edit_index = -1; // 수정할 사람이 저장된 인덱스

	printf("전화번호를 수정할 사람의 이름을 입력하세요: ");
	scanf("%s", edit_name);
	
	// 수정할 사람 검색
	for (int i = 0; i < num; i++) {
		if (strcmp(edit_name, name[i]) == 0) 
			edit_index = i; 
	}

	// 인덱스가 -1인 경우에는 수정할 사람이 존재하지 않는 것
	if (edit_index == -1) { 
		printf("존재하지 않는 이름입니다.\n");
		return;
	}
}
# Out:
#   File "<ipython-input-15-21c13536b9c2>", line 5
#     char name[MAX_SIZE][SIZE];
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 1.3.2) 전화번호 수정하기

# %% [markdown]
# #### 1.3.2 – 실습문제 1)
# strcpy를 이용하여 전화번호를 수정하시오.

# %% [markdown]
# <해답>

# %%
#include <stdio.h>
#include <string.h>
#define SIZE 30
#define MAX_SIZE 100
char name[MAX_SIZE][SIZE];
char phone[MAX_SIZE][SIZE];
int num = 0;

int main() {
	char edit_name[SIZE]; // 수정할 사람의 이름
	char edit_phone[SIZE]; // 수정할 사람의 전화번호
	int edit_index = -1; // 수정할 사람이 저장된 인덱스

	printf("전화번호를 수정할 사람의 이름을 입력하세요: ");
	scanf("%s", edit_name);

	// 수정할 사람 검색
	for (int i = 0; i < num; i++) {
		if (strcmp(edit_name, name[i]) == 0) 
			edit_index = i; // 해당 인덱스 저장
	}

	printf("수정할 전화번호를 입력하세요: ");
	scanf("%s", edit_phone);

	// 해당 인덱스의 번호를 새로 받은 전화번호로 수정
	for (int i = 0; i < SIZE; i++) {
		strcpy(phone[edit_index], edit_phone); 
	}
}
# Out:
#   File "<ipython-input-16-f5f520632d9b>", line 5
#     char name[MAX_SIZE][SIZE];
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Sub-Project 3. 수정 함수 구현하기

# %% [markdown]
# 주제: 입력받은 사람의 이름과 전화번호 중 수정할 사람을 이름으로 검색하고 수정할 전화번호를 입력하는 함수를 구현한다. 전화번호 입력 후 해당 사람의 전화번호가 수정되며, 저장되지 않은 사람을 검색할 경우 존재하지 않는 이름이라는 문구를 출력해준다. 이름과 전화번호의 인덱스가 같다는 점을 이용한다. 함수명은 edit() 으로 한다.

# %% [markdown]
# <결과 화면>
# ![image.png](attachment:image.png)

# %% [markdown]
# <해답>

# %%
// 입력된 전화번호를 수정하는 함수
void edit() {
	
	char edit_name[SIZE]; // 수정할 사람의 이름
	char edit_phone[SIZE]; // 수정할 사람의 전화번호
	int edit_index = -1; // 수정할 사람이 저장된 인덱스

	printf("전화번호를 수정할 사람의 이름을 입력하세요: ");
	scanf("%s", edit_name);

	// 수정할 사람 검색
	for (int i = 0; i < num; i++) {
	if (strcmp(edit_name, name[i]) == 0) 
	edit_index = i; 
	}
	// 인덱스가 -1인 경우에는 수정할 사람이 존재하지 않는 것
	if (edit_index == -1) { 
	printf("존재하지 않는 이름입니다.\n");
	return;
	}

	printf("수정할 전화번호를 입력하세요: ");
	scanf("%s", edit_phone);

	// 해당 인덱스의 번호를 새로 받은 전화번호로 수정
	for (int i = 0; i < SIZE; i++) {
	strcpy(phone[edit_index], edit_phone); 
	}

}
# Out:
#   File "<ipython-input-1-a9c949fb1f46>", line 1
#     // 입력된 전화번호를 수정하는 함수
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 1.4) 삭제 함수 작성하기

# %% [markdown]
# ### 1.4.1.) 삭제할 값 검색하기

# %% [markdown]
# #### 1.4.1 – 실습문제 1)
# 삭제할 사람의 이름을 입력받으시오.

# %% [markdown]
# <해답>

# %%
#include <stdio.h>
#include <string.h>
#define SIZE 30
#define MAX_SIZE 100
char name[MAX_SIZE][SIZE];
char phone[MAX_SIZE][SIZE];
int num = 0;

int main() {
	char erase_name[SIZE]; // 삭제할 사람의 이름
	int erase_index = -1; // 삭제할 사람이 저장된 인덱스

	printf("전화번호를 삭제할 사람의 이름을 입력하세요: ");
	scanf("%s", erase_name);
}
# Out:
#   File "<ipython-input-2-4a64a398898e>", line 5
#     char name[MAX_SIZE][SIZE];
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### 1.4.1 – 실습문제 2)
# name 배열에서 삭제할 사람을 검색하고, 찾은 사람의 인덱스를 다른 변수에 저장하시오.

# %% [markdown]
# <해답>

# %%
#include <stdio.h>
#include <string.h>
#define SIZE 30
#define MAX_SIZE 100
char name[MAX_SIZE][SIZE];
char phone[MAX_SIZE][SIZE];
int num = 0;

int main() {
	char erase_name[SIZE]; // 삭제할 사람의 이름
	int erase_index = -1; // 삭제할 사람이 저장된 인덱스

	printf("전화번호를 삭제할 사람의 이름을 입력하세요: ");
	scanf("%s", erase_name);

	// 삭제할 사람 검색
	for (int i = 0; i < num; i++) {
		if (strcmp(erase_name, name[i]) == 0)
			erase_index = i;
	}

}
# Out:
#   File "<ipython-input-3-854af491173d>", line 5
#     char name[MAX_SIZE][SIZE];
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### 1.4.1 – 실습문제 3)
# 검색한 값이 없을 경우 존재하지 않는 이름이라는 문구를 출력하시오. 이때 검색에 성공했을 경우 인덱스를 저장할 초기값을 설정하여 구분하면 쉽다.

# %% [markdown]
# <해답>

# %%
#include <stdio.h>
#include <string.h>
#define SIZE 30
#define MAX_SIZE 100
char name[MAX_SIZE][SIZE];
char phone[MAX_SIZE][SIZE];
int num = 0;

int main() {
	char erase_name[SIZE]; // 삭제할 사람의 이름
	int erase_index = -1; // 삭제할 사람이 저장된 인덱스

	printf("전화번호를 삭제할 사람의 이름을 입력하세요: ");
	scanf("%s", erase_name);

	// 삭제할 사람 검색
	for (int i = 0; i < num; i++) {
		if (strcmp(erase_name, name[i]) == 0) 
			erase_index = i; 
	}

	// 인덱스가 -1인 경우에는 삭제할 사람이 존재하지 않는 것
	if (erase_index == -1) { 
		printf("존재하지 않는 이름입니다.\n");
	}
}
# Out:
#   File "<ipython-input-4-d8b14c7f5af5>", line 5
#     char name[MAX_SIZE][SIZE];
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 1.4.2) 전화번호 삭제하기

# %% [markdown]
# #### 1.4.2 – 실습문제 1)
# strcpy를 이용하여 전화번호를 수정하시오. 이 때 삭제할 번호의 인덱스를 한 줄씩 당겨주는 느낌으로 이해하면 쉽다.

# %% [markdown]
# <해답>

# %%
#include <stdio.h>
#include <string.h>
#define SIZE 30
#define MAX_SIZE 100
char name[MAX_SIZE][SIZE];
char phone[MAX_SIZE][SIZE];
int num = 0;

int main() {
	char erase_name[SIZE]; // 삭제할 사람의 이름
	int erase_index = -1; // 삭제할 사람이 저장된 인덱스

	printf("전화번호를 삭제할 사람의 이름을 입력하세요: ");
	scanf("%s", erase_name);

	// 삭제할 사람 검색
	for (int i = 0; i < num; i++) {
		if (strcmp(erase_name, name[i]) == 0) 
			erase_index = i; 
	}

	// 인덱스가 -1인 경우에는 삭제할 사람이 존재하지 않는 것
	if (erase_index == -1) { 
		printf("존재하지 않는 이름입니다.\n");
	}

	for (int i = erase_index; i < num - 1; i++) {
		strcpy(name[i], name[i + 1]);
		strcpy(phone[i], phone[i + 1]);
	}
}
# Out:
#   File "<ipython-input-5-15970552708b>", line 5
#     char name[MAX_SIZE][SIZE];
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Sub-Project 4. 삭제 함수 구현하기

# %% [markdown]
# 주제: 입력된 전화번호 중 이름으로 검색하여 해당 사람의 정보를 삭제하는 함수를 구현한다. 검색한 사람이 없을 경우 존재하지 않는 이름이라는 문구를 출력한다. 최대 저장 공간이 100인 점을 고려하여, 해당 인덱스를 비우기보다는 뒤에 저장된 내용들을 한 인덱스 씩 앞당기고, 저장된 총 인원을 줄여주어 삭제를 구현한다. 함수명은 erase()로 한다.

# %% [markdown]
# <결과 화면>
# ![image.png](attachment:image.png)

# %% [markdown]
# <해답>

# %%
//입력된 전화번호를 삭제하는 함수
void erase() { 

	char erase_name[SIZE]; // 삭제할 사람의 이름
	int erase_index = -1; // 삭제할 사람이 저장된 인덱스

	printf("전화번호를 삭제할 사람의 이름을 입력하세요: ");
	scanf("%s", erase_name);

	// 삭제할 사람 검색
	for (int i = 0; i < num; i++) {
		if (strcmp(erase_name, name[i]) == 0)
			erase_index = i; 
	}

	// 인덱스가 -1인 경우에는 삭제할 사람이 존재하지 않는 것
	if (erase_index == -1) { 
		printf("존재하지 않는 이름입니다.\n");
		return;
	}
	else
		num--;

	// 저장된 값들을 한 인덱스씩 당겨서 삭제
	for (int i = erase_index; i < num - 1; i++) {
		strcpy(name[i], name[i + 1]);
		strcpy(phone[i], phone[i + 1]);
	}
}
# Out:
#   File "<ipython-input-6-360af3979877>", line 1
#     //입력된 전화번호를 삭제하는 함수
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 1.5) 검색 함수 작성하기

# %% [markdown]
# ### 1.5.1) 검색하기

# %% [markdown]
# #### 1.5.1 – 실습문제 1)
# 검색할 사람의 이름을 입력받으시오.

# %% [markdown]
# <해답>

# %%
#include <stdio.h>
#include <string.h>
#define SIZE 30
#define MAX_SIZE 100
char name[MAX_SIZE][SIZE];
char phone[MAX_SIZE][SIZE];
int num = 0;

int main() {
	char search_name[SIZE]; // 검색할 사람의 이름
	
	printf("전화번호를 검색할 사람의 이름을 입력하세요: ");
	scanf("%s", search_name);
}
# Out:
#   File "<ipython-input-7-2d37eb1b4408>", line 5
#     char name[MAX_SIZE][SIZE];
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### 1.5.1 – 실습문제 2)
# name 배열에서 검색할 사람을 찾고, 찾은 사람의 인덱스를 다른 변수에 저장하시오.

# %% [markdown]
# <해답>

# %%
#include <stdio.h>
#include <string.h>
#define SIZE 30
#define MAX_SIZE 100
char name[MAX_SIZE][SIZE];
char phone[MAX_SIZE][SIZE];
int num = 0;

int main() {
	char search_name[SIZE]; // 검색할 사람의 이름
	int search_index = -1; // 검색할 사람이 저장된 인덱스

	printf("전화번호를 검색할 사람의 이름을 입력하세요: ");
	scanf("%s", search_name);

	//검색
	for (int i = 0; i < num; i++) {
		if (strcmp(search_name, name[i]) == 0) 
			search_index = i;
	}

}
# Out:
#   File "<ipython-input-8-f0eab3622a50>", line 5
#     char name[MAX_SIZE][SIZE];
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 1.5.2) 전화번호 출력하기

# %% [markdown]
# #### 1.5.2 – 실습문제 1)
# 검색한 값이 없을 경우 존재하지 않는 이름이라는 문구를 출력하시오. 이때 검색에 성공했을 경우 인덱스를 저장할 초기값을 설정하여 구분하면 쉽다. 검색에 성공했을 경우 검색한 전화번호를 출력하시오.

# %% [markdown]
# <해답>

# %%
#include <stdio.h>
#include <string.h>
#define SIZE 30
#define MAX_SIZE 100
char name[MAX_SIZE][SIZE];
char phone[MAX_SIZE][SIZE];
int num = 0;

int main() {
	char search_name[SIZE]; // 검색할 사람의 이름
	int search_index = -1; // 검색할 사람이 저장된 인덱스

	printf("전화번호를 검색할 사람의 이름을 입력하세요: ");
	scanf("%s", search_name);

	// 검색
	for (int i = 0; i < num; i++) {
		if (strcmp(search_name, name[i]) == 0) 
			search_index = i; 
	}

	// 인덱스가 -1인 경우에는 검색한 사람이 존재하지 않는 것
	if (search_index == -1) { 
		printf("존재하지 않는 이름입니다.\n");
		return;
	}
	else
		printf("전화번호: %s\n", phone[search_index]);

}
# Out:
#   File "<ipython-input-9-3f8aa1f5942f>", line 5
#     char name[MAX_SIZE][SIZE];
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Sub-Project 5. 검색 함수 구현하기

# %% [markdown]
# 주제: 입력된 전화번호를 이름으로 검색하여 출력하는 함수를 구현한다. 검색한 사람이 없을 경우 존재하지 않는 이름이라는 문구를 출력한다. 함수명은 search()로 한다.

# %% [markdown]
# <결과 화면>
# ![image.png](attachment:image.png)
#
# <해답>

# %%
//입력된 전화번호를 검색하는 함수
void search() { 

	char search_name[SIZE]; // 검색할 사람의 이름
	int search_index = -1; // 검색할 사람이 저장된 인덱스

	printf("전화번호를 검색할 사람의 이름을 입력하세요: ");
	scanf("%s", search_name);

	// 검색
	for (int i = 0; i < num; i++) {
		if (strcmp(search_name, name[i]) == 0) 
			search_index = i; 
	}

	// 인덱스가 -1인 경우에는 검색한 사람이 존재하지 않는 것
	if (search_index == -1) { 
		printf("존재하지 않는 이름입니다.\n");
		return;
	}
	else
		printf("전화번호: %s\n", phone[search_index]);

}
# Out:
#   File "<ipython-input-10-befe0f655e91>", line 1
#     //입력된 전화번호를 검색하는 함수
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 1.6) 저장함수 작성하기

# %% [markdown]
# ### 1.6.1) 파일 입출력

# %% [markdown]
# #### 1.6.1 – 실습문제 1)
# name 배열과 phone 배열에 있는 이름과 전화번호들을 텍스트 파일로 저장하시오.

# %% [markdown]
# <해답>

# %%
#include <stdio.h>
#include <string.h>
#define SIZE 30
#define MAX_SIZE 100
char name[MAX_SIZE][SIZE];
char phone[MAX_SIZE][SIZE];
int num = 0;

int main() {
	FILE *fp = fopen("call.txt", "w");    // call.txt 파일을 쓰기 모드(w)로 열기.

	// 파일에 문자열 저장
	for (int i = 0; i < num; i++) {
		fputs(name[i], fp);   
		fputs("\t", fp);
		fputs(phone[i], fp);
		fputs("\n", fp);
	}

	fclose(fp); // 파일 포인터 닫기
}
# Out:
#   File "<ipython-input-11-2d7fa096120f>", line 5
#     char name[MAX_SIZE][SIZE];
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Sub-Project 6. 저장 함수 구현하기

# %% [markdown]
# 주제: 입력된 이름과 전화번호들을 텍스트 파일로 저장하는 함수이다. 함수명은 save()로 한다.

# %% [markdown]
# <결과 화면>
# ![image.png](attachment:image.png)

# %% [markdown]
# <해답>

# %%
//입력된 전화번호를 파일로 저장하는 함수
void save() { 

	FILE *fp = fopen("call.txt", "w"); 

	// 파일에 문자열 저장
	for (int i = 0; i < num; i++) {
		fputs(name[i], fp);   
		fputs("\t", fp);
		fputs(phone[i], fp);
		fputs("\n", fp);
	}

	fclose(fp); 

	printf("저장되었습니다.\n");
}
# Out:
#   File "<ipython-input-12-8aedc9bf8b55>", line 1
#     //입력된 전화번호를 파일로 저장하는 함수
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Main-Project 1. 전화번호부 구현하기

# %% [markdown]
# 주제: 전화번호부 구현하기
# 내용: 콘솔창에서 전화번호를 입력, 수정, 삭제, 검색할 수 있으며 저장 버튼을 누르면 전화번호가 파일로 저장되는 프로그램을 만들 것이다.
#
# 프로그램 기능
# 1. 입력: 이름과 전화번호를 입력한다. 최대 저장 가능 공간은 100으로 한다.
# 2. 수정: 입력된 전화번호를 수정한다. 이름으로 검색하여 해당하는 사람의 전화번호를 수정한다.
# 3. 삭제: 입력된 전화번호를 삭제한다. 이름으로 검색하여 해당하는 사람의 전화번호를 삭제한다.
# 4. 검색: 이름을 검새하면 해당하는 사람의 전화번호를 출력한다.
# 5. 저장: 입력된 이름과 전화번호들을 파일로 저장한다.
# 사용자가 종료를 입력하기 전까지 프로그램이 반복된다.

# %% [markdown]
# <결과 화면>
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <해답>

# %%
#include <stdio.h>
#include <string.h>
#define SIZE 30
#define MAX_SIZE 100

char name[MAX_SIZE][SIZE]; // 이름을 저장하는 배열
char phone[MAX_SIZE][SIZE]; // 전화번호를 저장하는 배열
int num = 0; // 사람과 전화번호를 num 변수로 연결

void input();
void edit();
void erase();
void search();
void save();

int main() {

	printf("*************전화번호부*************\n\n");
	printf("    1.입력    2.수정    3.삭제\n");
	printf("    4.검색    5.저장    6.종료\n");
	printf("************************************\n");

	int menu = 0;

	while (1) {
		printf("\n사용자 입력>> ");
		scanf("%d", &menu);

		if (menu == 6)
			break;
		else if (menu == 1)
			input();
		else if (menu == 2)
			edit();
		else if (menu == 3)
			erase();
		else if (menu == 4)
			search();
		else if (menu == 5)
			save();
		else
			printf("잘못된 입력입니다. 다시 입력하세요,\n");
	}
}

// 전화번호를 새로 입력하는 함수
void input() { 

	if (num >= MAX_SIZE) {
		printf("저장공간이 부족합니다.\n");
		return;
	}

	printf("이름: ");
	scanf("%s", name[num]);

	printf("전화번호: ");
	scanf("%s", phone[num]);

	num++;
}

// 입력된 전화번호를 수정하는 함수
void edit() { 

	char edit_name[SIZE]; // 수정할 사람의 이름
	char edit_phone[SIZE]; // 수정할 사람의 전화번호
	int edit_index = -1; // 수정할 사람이 저장된 인덱스

	printf("전화번호를 수정할 사람의 이름을 입력하세요: ");
	scanf("%s", edit_name);

	// 수정할 사람 검색
	for (int i = 0; i < num; i++) {
		if (strcmp(edit_name, name[i]) == 0) 
			edit_index = i; 
	}

	// 인덱스가 -1인 경우에는 수정할 사람이 존재하지 않는 것
	if (edit_index == -1) { 
		printf("존재하지 않는 이름입니다.\n");
		return;
	}

	printf("수정할 전화번호를 입력하세요: ");
	scanf("%s", edit_phone);

	// 해당 인덱스의 번호를 새로 받은 전화번호로 수정
	for (int i = 0; i < SIZE; i++) {
		strcpy(phone[edit_index], edit_phone); 
	}

}

//입력된 전화번호를 삭제하는 함수
void erase() { 

	char erase_name[SIZE]; // 삭제할 사람의 이름
	int erase_index = -1; // 삭제할 사람이 저장된 인덱스

	printf("전화번호를 삭제할 사람의 이름을 입력하세요: ");
	scanf("%s", erase_name);

	// 삭제할 사람 검색
	for (int i = 0; i < num; i++) {
		if (strcmp(erase_name, name[i]) == 0)
			erase_index = i; 
	}

	// 인덱스가 -1인 경우에는 삭제할 사람이 존재하지 않는 것
	if (erase_index == -1) { 
		printf("존재하지 않는 이름입니다.\n");
		return;
	}
	else
		num--;

	// 저장된 값들을 한 인덱스씩 당겨서 삭제
	for (int i = erase_index; i < num - 1; i++) {
		strcpy(name[i], name[i + 1]);
		strcpy(phone[i], phone[i + 1]);
	}
}

//입력된 전화번호를 검색하는 함수
void search() { 

	char search_name[SIZE]; // 검색할 사람의 이름
	int search_index = -1; // 검색할 사람이 저장된 인덱스

	printf("전화번호를 검색할 사람의 이름을 입력하세요: ");
	scanf("%s", search_name);

	// 검색
	for (int i = 0; i < num; i++) {
		if (strcmp(search_name, name[i]) == 0) 
			search_index = i; 
	}

	// 인덱스가 -1인 경우에는 검색한 사람이 존재하지 않는 것
	if (search_index == -1) { 
		printf("존재하지 않는 이름입니다.\n");
		return;
	}
	else
		printf("전화번호: %s\n", phone[search_index]);

}

//입력된 전화번호를 파일로 저장하는 함수
void save() { 

	FILE *fp = fopen("call.txt", "w"); 

	// 파일에 문자열 저장
	for (int i = 0; i < num; i++) {
		fputs(name[i], fp);   
		fputs("\t", fp);
		fputs(phone[i], fp);
		fputs("\n", fp);
	}

	fclose(fp); 

	printf("저장되었습니다.\n");
}
# Out:
#   File "<ipython-input-13-c6e189599b7f>", line 6
#     char name[MAX_SIZE][SIZE]; // 이름을 저장하는 배열
#          ^
# SyntaxError: invalid syntax
